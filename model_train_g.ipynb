# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import scipy as sp
import seaborn as sns
import sklearn
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# Tensorflow
import tensorflow as tf
import tensorflow_hub as hub

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa

from sklearn.model_selection import train_test_split

# %%
import splitfolders
#splitfolders.ratio('C:/Users/Krow/Documents/Uni/PI/archive_main/asl_alphabet_train/asl_alphabet_train/', output="C:/Users/Krow/Documents/Uni/PI/dataset_main/", seed=1337, ratio=(.6, .2, .2))
#splitfolders.ratio('C:/Users/Krow/Documents/Uni/PI/archive_simple/asl_dataset/', output="C:/Users/Krow/Documents/Uni/PI/dataset_sec/", seed=1337, ratio=(0, 0.5,0.5))

# %% [markdown]
# # Consts

# %%
#batch_size = 32
image_size = 128
target_dim = (image_size, image_size)
nm_classes  = 5

#image_count = 87000
#train_dir_real  = 'C:/Users/Krow/Documents/Uni/PI/dataset_main/train'
#val_dir_real  = 'C:/Users/Krow/Documents/Uni/PI/dataset_main/val/'
#test_dir_real = 'C:/Users/Krow/Documents/Uni/PI/dataset_main/test/'
train_dir_synth = 'C:/Users/Krow/Documents/Uni/PI/dataset_sec/train_synth/'

train_dir_real  = 'C:/Users/Krow/Documents/Uni/PI/dataset_sec/train'
val_dir_real  = 'C:/Users/Krow/Documents/Uni/PI/dataset_sec/val/'
test_dir_real = 'C:/Users/Krow/Documents/Uni/PI/dataset_sec/test/'

# %% [markdown]
# # Load Dataset

# %%
from imgaug import augmenters as iaa

aug1 = iaa.GaussianBlur(sigma=(0, 2.0))
aug2 = iaa.AdditiveGaussianNoise(0,0.05 * 255)

def additional_augmenation(image):
    #image = aug1.augment_image(image)
    image = aug1.augment_image(image)
    return image

# %%
#Augmentation
# rotation_range=30, fill_mode='nearest'
# width_shift_range=0.2, height_shift_range=0.2
# horizontal_flip=True, vertical_flip=True
# brightness_range=[0.5,1.1]
# zoom_range=0.3
# preprocessing_function = iaa.GaussianBlur(sigma=(0, 3.0))

train_image_generator = ImageDataGenerator(rescale=1./255,
rotation_range=5,
#width_shift_range=0.05, height_shift_range=0.05,
#brightness_range=[0.95,1.05],
#zoom_range=[1,1.2]
#preprocessing_function = additional_augmenation
)
train_data_gen = train_image_generator.flow_from_directory(directory=train_dir_synth, shuffle=False, target_size = target_dim)
# Out:
# Found 534 images belonging to 5 classes.

# %%
validation_image_generator = ImageDataGenerator(rescale=1./255,
rotation_range=5)
validation_data_gen = validation_image_generator.flow_from_directory(directory=val_dir_real, shuffle=False, target_size = target_dim)
# Out:
# Found 140 images belonging to 5 classes.

# %%
test_image_generator = ImageDataGenerator(rescale=1./255)
test_data_gen = test_image_generator.flow_from_directory(directory=test_dir_real, shuffle=False, target_size = target_dim)
# Out:
# Found 210 images belonging to 5 classes.

# %%
def display_samples(data_gen, title):
    classes = dict()
    for key,val in data_gen.class_indices.items():
        classes[val]= key

    sample_images, sample_labels = next(data_gen)

    plt.figure(figsize=(10,3))
    plt.subplots_adjust(hspace=0.5)
    for n in range(5):
        plt.subplot(1,5,n+1)
        plt.imshow(sample_images[n])
        plt.title(classes[np.argmax(sample_labels[n])])
        plt.axis("off")
        _ = plt.suptitle(title)

#display_samples(train_data_gen, "Sample Training Images")
display_samples(test_data_gen, "Sample Test Images")
display_samples(validation_data_gen, "Sample Validation Images")

# %%
num_classes = len(validation_data_gen.class_indices)

model = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/imagenet/inception_resnet_v2/feature_vector/5",
                   trainable=False),  # Can be True, see below.
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
model.build([None, image_size, image_size, 3])  # Batch input shape.

model.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1536)              54336736
#
#  dense (Dense)               (None, 5)                 7685
#
# =================================================================
# Total params: 54,344,421
# Trainable params: 7,685
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
metrics=['acc'])

# %%
train_steps_per_epoch = np.ceil(validation_data_gen.samples/validation_data_gen.batch_size)
#val_steps_per_epoch = np.ceil(validation_data_gen.samples/validation_data_gen.batch_size)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, verbose=1, min_delta=0.001)

epochs = 100

history = model.fit(validation_data_gen,
                    epochs=epochs,
                    steps_per_epoch=train_steps_per_epoch,
                    #validation_data=validation_data_gen,
                    #validation_steps=val_steps_per_epoch,
                    verbose=1,
                    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 16s 79ms/step - loss: 3.4870 - acc: 0.1357
# Epoch 2/100
# 5/5 [==============================] - 1s 109ms/step - loss: 1.8452 - acc: 0.3571
# Epoch 3/100
# 5/5 [==============================] - 1s 89ms/step - loss: 1.2913 - acc: 0.4500
# Epoch 4/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.7202 - acc: 0.7000
# Epoch 5/100
# 5/5 [==============================] - 1s 91ms/step - loss: 0.5633 - acc: 0.7571
# Epoch 6/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.3801 - acc: 0.8429
# Epoch 7/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.2484 - acc: 0.9429
# Epoch 8/100
# 5/5 [==============================] - 1s 94ms/step - loss: 0.2155 - acc: 0.9571
# Epoch 9/100
# 5/5 [==============================] - 1s 87ms/step - loss: 0.1921 - acc: 0.9500
# Epoch 10/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1262 - acc: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 1s 92ms/step - loss: 0.1323 - acc: 0.9929
# Epoch 12/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1156 - acc: 0.9929
# Epoch 13/100
# 5/5 [==============================] - 1s 88ms/step - loss: 0.1124 - acc: 0.9929
# Epoch 14/100
# 5/5 [==============================] - 1s 96ms/step - loss: 0.1053 - acc: 0.9929
# Epoch 15/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0887 - acc: 0.9929
# Epoch 16/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0806 - acc: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0865 - acc: 0.9929
# Epoch 18/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0643 - acc: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 1s 87ms/step - loss: 0.0713 - acc: 0.9929
# Epoch 20/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0575 - acc: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 104ms/step - loss: 0.0613 - acc: 0.9929
# Epoch 22/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0492 - acc: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0528 - acc: 0.9929
# Epoch 24/100
# 5/5 [==============================] - 1s 89ms/step - loss: 0.0500 - acc: 0.9929
# Epoch 25/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0418 - acc: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 1s 95ms/step - loss: 0.0453 - acc: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0349 - acc: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0457 - acc: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 1s 95ms/step - loss: 0.0380 - acc: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 1s 94ms/step - loss: 0.0404 - acc: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0387 - acc: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 1s 91ms/step - loss: 0.0362 - acc: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0313 - acc: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0291 - acc: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0351 - acc: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 104ms/step - loss: 0.0332 - acc: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 1s 89ms/step - loss: 0.0257 - acc: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0253 - acc: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 1s 89ms/step - loss: 0.0257 - acc: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0269 - acc: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 1s 92ms/step - loss: 0.0209 - acc: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0241 - acc: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0251 - acc: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.0256 - acc: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 1s 90ms/step - loss: 0.0199 - acc: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 1s 91ms/step - loss: 0.0224 - acc: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 1s 94ms/step - loss: 0.0248 - acc: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 1s 93ms/step - loss: 0.0187 - acc: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0209 - acc: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 1s 94ms/step - loss: 0.0199 - acc: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0197 - acc: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0177 - acc: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.0160 - acc: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0171 - acc: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 1s 87ms/step - loss: 0.0155 - acc: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 1s 91ms/step - loss: 0.0202 - acc: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0189 - acc: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0147 - acc: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 1s 95ms/step - loss: 0.0189 - acc: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 1s 88ms/step - loss: 0.0148 - acc: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0143 - acc: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 1s 88ms/step - loss: 0.0114 - acc: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 104ms/step - loss: 0.0141 - acc: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0132 - acc: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 1s 96ms/step - loss: 0.0111 - acc: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0135 - acc: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0154 - acc: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0136 - acc: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0161 - acc: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0120 - acc: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0131 - acc: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 1s 88ms/step - loss: 0.0106 - acc: 1.0000
# Epoch 72: early stopping

# %%
class_names = np.empty([len(test_data_gen.class_indices)], dtype=object, order="C")
for key, val in test_data_gen.class_indices.items():
    class_names[val] = key
    
test_data_gen.reset()
predicted_batch = model.predict(test_data_gen)
# Out:
# 7/7 [==============================] - 3s 95ms/step

# %%
plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_data_gen)

print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 7/7 [==============================] - 3s 67ms/step - loss: 0.0503 - acc: 0.9905
# Test accuracy: 0.9904761910438538
# Test loss: 0.05030835419893265

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

classes = ['A', 'E', 'I', 'O', 'U']

predicted_id = np.argmax(predicted_batch, axis=1)

cm = confusion_matrix(test_data_gen.classes, predicted_id)
plt.figure(figsize=(7,6))
ax = sns.heatmap(cm,annot=True, fmt='.0f', linewidths=.5, square=True,cmap='Blues_r')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format(accuracy_score(test_data_gen.classes,predicted_id))
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.9904761904761905')

# %%
#model.save('asl_sec_full_synth_resnet_96_19.h5')

# %% [markdown]
# # Dataset Visualization

# %% [markdown]
# # Model & Criterion

# %% [markdown]
# # Model Fitting

# %% [markdown]
# # Prediction

# %% [markdown]
# # Save Model

# %%
#model.save('asl_model_synth_B.h5')

# %% [markdown]
# # Load Model to avoid retraining

# %%
# load model
#model = tf.keras.models.load_model('asl_model_synth_B.h5')

# %% [markdown]
# # Load real data

# %% [markdown]
# # Predictions: Real Data
